# %% [markdown]
# # scVI-tools (single-cell variational inference tools)
# [공식 문서](https://docs.scvi-tools.org/en/stable/user_guide/index.html)

# %%
import scanpy as sc
import scvi
from matplotlib import rcParams

# %% [markdown]
# # Load data

# %%
folder_path = "C:/Users/heung/OneDrive/Documents/scData/16. Siglec-9_GSE235913/sc/"
adata = sc.read(folder_path + "preprocessed_adata.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 126563 × 41541
#     obs: 'sample', 'n_genes', 'total_counts', 'pct_counts_mito', 'pct_counts_ribo'
#     var: 'n_cells'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
sc.pp.filter_genes(adata, min_cells=30)
adata
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sc.pp.filter_genes(adata, min_cells=30)
#       2 adata
#
# File c:\Users\heung\anaconda3\Lib\site-packages\legacy_api_wrap\__init__.py:80, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      77 @wraps(fn)
#      78 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      79     if len(args_all) <= n_positional:
# ---> 80         return fn(*args_all, **kw)
#      82     args_pos: P.args
#      83     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File c:\Users\heung\anaconda3\Lib\site-packages\scanpy\preprocessing\_simple.py:276, in filter_genes(data, min_counts, min_cells, max_counts, max_cells, inplace, copy)
#     274     else:
#     275         adata.var["n_cells"] = number
# --> 276     adata._inplace_subset_var(gene_subset)
#     277     return adata if copy else None
#     279 X = data  # proceed with processing the data matrix
#
# File c:\Users\heung\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1220, in AnnData._inplace_subset_var(self, index)
#    1214 def _inplace_subset_var(self, index: Index1D):
#    1215     """\
#    1216     Inplace subsetting along variables dimension.
#    1217
#    1218     Same as `adata = adata[:, index]`, but inplace.
#    1219     """
# -> 1220     adata_subset = self[:, index].copy()
#    1222     self._init_as_actual(adata_subset)
#
# File c:\Users\heung\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1504, in AnnData.copy(self, filename)
#    1497 if not self.isbacked:
#    1498     if self.is_view and self._has_X():
#    1499         # TODO: How do I unambiguously check if this is a copy?
#    1500         # Subsetting this way means we don’t have to have a view type
#    1501         # defined for the matrix, which is needed for some of the
#    1502         # current distributed backend. Specifically Dask.
#    1503         return self._mutated_copy(
# -> 1504             X=_subset(self._adata_ref.X, (self._oidx, self._vidx)).copy()
#    1505         )
#    1506     else:
#    1507         return self._mutated_copy()
#
# File c:\Users\heung\anaconda3\Lib\functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\heung\anaconda3\Lib\site-packages\anndata\_core\index.py:165, in _subset_spmatrix(a, subset_idx)
#     163         first_idx = np.where(first_idx)[0]
#     164     subset_idx = (first_idx.reshape(-1, 1), *subset_idx[1:])
# --> 165 return a[subset_idx]
#
# File c:\Users\heung\anaconda3\Lib\site-packages\scipy\sparse\_index.py:76, in IndexMixin.__getitem__(self, key)
#      74         return self._get_sliceXslice(row, col)
#      75     elif col.ndim == 1:
# ---> 76         return self._get_sliceXarray(row, col)
#      77     raise IndexError('index results in >2 dimensions')
#      78 elif row.ndim == 1:
#
# File c:\Users\heung\anaconda3\Lib\site-packages\scipy\sparse\_csr.py:208, in _csr_base._get_sliceXarray(self, row, col)
#     207 def _get_sliceXarray(self, row, col):
# --> 208     return self._major_slice(row)._minor_index_fancy(col)
#
# File c:\Users\heung\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:797, in _cs_matrix._minor_index_fancy(self, idx)
#     795 res_indices = np.empty(nnz, dtype=idx_dtype)
#     796 res_data = np.empty(nnz, dtype=self.dtype)
# --> 797 csr_column_index2(col_order, col_offsets, len(self.indices),
#     798                   indices, self.data, res_indices, res_data)
#     799 return self.__class__((res_data, res_indices, res_indptr),
#     800                       shape=new_shape, copy=False)
#
# KeyboardInterrupt:

# %%
adata.obs.groupby(['sample']).count()
# adata.obs.groupby(['condition']).count()

# %% [markdown]
# # batch 확인

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# running time: 2m 8s

# %%
sc.settings.set_figure_params(dpi=100, figsize = (7, 7))
sc.pl.umap(
    adata,
    color = 'sample',
)

# %% [markdown]
# # Batch effect correction by scVI

# %%
# pick the top 3000 highly variable genes
# you can pick more if you had more cells
# 3000 genes in 10000 cells is a good number
# gene 개수가 cell 개수의 절반은 되야 한다는 카더라가 있음
# **나는 안돌림**
sc.pp.highly_variable_genes(adata, n_top_genes = 3000, subset = True, layer = 'counts',
                            flavor = 'seurat_v3', batch_key = 'condition')

# %%
# making the scVI model
# GPU 안쓰면 개느림. Cuda <- 필수
# 37k cells and 16k genes, 215 epochs, RTX3070 -> 약 11분 소요
# 143k cells and 30k genes, 56 epochs, RTX3070 -> 약 18분 소요
scvi.model.SCVI.setup_anndata(
    adata,
    layer = 'counts',
    continuous_covariate_keys = ['pct_counts_mito', 'pct_counts_ribo', 'total_counts'],
    batch_key = 'sample'
)
model = scvi.model.SCVI(
    adata,
    n_layers = 3,
    n_latent = 30,
    gene_likelihood = 'nb',
)
# Out:
# c:\Users\heung\anaconda3\Lib\site-packages\scvi\data\fields\_base_field.py:64: UserWarning: adata.layers[counts] does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)

# %%
# model.train(max_epochs = 200)
model.train()
# init train loss = 5.1e+3
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3070') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\heung\anaconda3\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# Epoch 63/63: 100%|██████████| 63/63 [18:25<00:00, 17.48s/it, v_num=1, train_loss_step=4.95e+3, train_loss_epoch=4.92e+3]
# `Trainer.fit` stopped: `max_epochs=63` reached.
# Epoch 63/63: 100%|██████████| 63/63 [18:25<00:00, 17.55s/it, v_num=1, train_loss_step=4.95e+3, train_loss_epoch=4.92e+3]

# %%
# get the latent space
adata.obsm['X_scVI'] = model.get_latent_representation()
# model.get_latent_representation().shape

# get scVI normalized data
adata.layers['scvi_normalized'] = model.get_normalized_expression(library_size = 1e4)

# running time: 40s
# running time: 26s

# %% [markdown]
# # Batch regression 확인

# %%
# 기본적인 clustering
# sc.pp.pca(adata)
sc.pp.neighbors(adata, use_rep = 'X_scVI')
sc.tl.umap(adata)

# running time: 1m 51s
# running time: 1m 37s

# %%
sc.settings.set_figure_params(dpi=100, figsize = (7, 7))

sc.pl.umap(
    adata,
    color = ['sample'],
    # groups = ['Pt1'],
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 126563 × 41541
#     obs: 'sample', 'n_genes', 'total_counts', 'pct_counts_mito', 'pct_counts_ribo', '_scvi_batch', '_scvi_labels'
#     var: 'n_cells'
#     uns: 'sample_colors', '_scvi_uuid', '_scvi_manager_uuid', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', '_scvi_extra_continuous_covs', 'X_scVI'
#     layers: 'counts', 'scvi_normalized'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# # Save the integrated data and scVI model

# %%
adata.write_h5ad(folder_path + "adata_scVI.h5ad")
model.save(folder_path + 'model/')  # trained model 저장
